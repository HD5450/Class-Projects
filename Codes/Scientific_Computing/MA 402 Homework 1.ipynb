# %%
import numpy as np
import math

def myroots(a, b, c):
  x_pos = (-b + math.sqrt(b**2 - 4*a*c))/(2*a)
  x_neg = (-b - math.sqrt(b**2 - 4*a*c))/(2*a)
  print(x_pos, x_neg)

print(np.roots([1,10**8,1]))
myroots(1,10**8,1)

def myroots_acc(a,b,c):
  x_pos = 
  print(x_pos)
myroots_acc(1,10**8,1)
# Out:
# [-1.e+08 -1.e-08]
# -7.450580596923828e-09 -100000000.0
# 7.450580596923828e-09

# %%
from numpy import *

h = 0.01 #h = 10^-2
p = linspace(0, 1, 101) #points
e = exp(p) #values for e from x = 0 to 1
f1 = zeros(len(p)) #zeros for function 1
f2 = zeros(len(p)) #zeros for function 2

for i in range(0, 100):
  f1[i] = (e[i + 1] - e[i])/h 
  
for i in range(0, 100):
  f2[i] = (e[i - 1] - e[i + 1])/(2*h)
  
print (f1, f2)
