# %% [markdown]
# # Hubble's Law

# %% [markdown]
# * Names in Group: .... put yours here
# * Group #: ... put yours here

# %%
# %matplotlib inline
# remember, you can switch "inline" to "notebook" if you prefer
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as c

# %%
# Data from Hubble 1929 
# first column: distance in Mparsecs
# second column: velocity in km/s 
data = np.array([
        (0.032,170),
        (0.034,290),
        (0.214,-130),
        (0.263,-70),
        (0.275,-185),
        (0.275,-220),
        (0.45,200),
        (0.5,290),
        (0.5,270),
        (0.63,200),
        (0.8,300),
        (0.9,30),
        (0.9,650),
        (0.9,150),
        (0.9,500),
        (1.0,920),
        (1.1, 450),
        (1.1, 500), 
        (1.4, 500),
        (1.7, 960),
        (2.0, 500),
        (2.0, 800),
        (2.0, 850),
        (2.0, 1090)
        ])
x = data[:,0]
y = data[:,1]

# %%
print('Linear regression using stats.linregress')
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print('Calculate std error on fit estimates')
mx = np.mean(x)
sx2 = ((x-mx)**2).sum()
sd_intercept = std_err * np.sqrt(1./len(x) + mx*mx/sx2)
sd_slope = std_err * np.sqrt(1./sx2)
print('Slope=%.2f +/- %.2f    Intercept=%.2f +/- %.2f' % (slope, sd_slope, intercept, sd_intercept))

# %%
# be sure to improve the graph by include labels and units, before turning it in
plt.plot(x, y, 'ro', label='Hubble 1929')
x0 = np.array([0,2.1])
plt.plot(x0, slope*x0, 'k-', label='$H_0$ = %0.f UNITS' % slope)
plt.xlabel('Put X label here [UNITS]')
plt.ylabel('Put Y label here [UNITS]')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Questions to Answer

# %% [markdown]
# **The linear regression function returned values with +/- uncertainty on the intercept. Use these values to discuss whether or not Hubble's Law passes through the point (0,0)? Should it? Does it?**

# %% [markdown]
# Answer:

# %% [markdown]
# **Some of Hubble's listed datapoints have negative values: is this physical? If yes, how should they be interpreted?**

# %% [markdown]
# Answer:

# %% [markdown]
# Next, we're going to put these values into other units so that we can more easily interpret Hubble's contstant. Here are some examples of how to use physics constants within Python: https://docs.scipy.org/doc/scipy-0.18.1/reference/constants.html

# %%
1.0 * c.eV   #will convert to Joules

# %% [markdown]
# ** Consider the spectral line associated with the ionization of hydrogen. For the last nebula in the dataset, what wavelength would Hubble have observed? [you will need to create the rigth equation to put here] **

# %%
np.sqrt(c.c * c.Planck)

# %% [markdown]
# **What value [with units] did you observe for the Hubble Constant? Is this value consistent (within error bars, which you should also calculate) with the currently accepted value? Discuss some possible sources of error, and decide to what extent you think they are responible for the level of disagreement observed.**

# %% [markdown]
# Answer:

# %% [markdown]
# ** Assuming that $H_0$ is a constant, and started at size 0 at the Big Bang, use your value to calculate the age of the universe in years. [you will need to create the right equation to put here: this is an *erroneous* value of $H_0$ and the units are NOT correct!] **

# %%
1.23 * c.parsec * (365. * 24. * 3600.)

# %% [markdown]
# **Repeat this calcution for the currently accepted value for $H_0$ [use Google and/or your book]**

# %%
1.23 * c.parsec /(365. * 24. * 3600.)
