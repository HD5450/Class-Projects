# %% [markdown]
# Edit the code below and add a print instruction to print the content of the arrays. Compare your result with your friend’s  result. Are they the same?

# %%
import numpy as np


array_size= 10000000

seed = 4
np.random.seed(seed)

my_array1=np.random.rand(array_size)
my_array2=np.random.rand(array_size)

print(my_array1)
print(my_array2)
# Out:
# [0.96702984 0.54723225 0.97268436 ... 0.0664702  0.11850422 0.77935834]
# [0.72704591 0.38578804 0.34552253 ... 0.98343487 0.13922178 0.9457197 ]

# %% [markdown]
# my_array1 and my_array2 are two one dimensional arrays. Their dot product (also known as scalar product)  would be a single scalar. Implement this dot product on these two arrays using looping. If you don't remember what was the syntax for looping in Python that's all OK. Google it or ask your friends!
#
#
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/5bd0b488ad92250b4e7c2f8ac92f700f8aefddd5)

# %%
product = 0
for i in range (array_size):
  product += my_array1[i] * my_array2[i]
print(product)
# Out:
# 2499595.90670939

# %% [markdown]
# We like to calculate dot product of these arrays, but this time instead of looping, consider my_array1 and my_array2 as two vectors, and use numpy's dot operator to find the result. Does the result the same as what you find above?
#
# Feel free to use Google or any other online resource (or just ask your friend's help) to find the syntax for dot product.

# %%
np.dot(my_array1, my_array2)
# Out:
# 2499595.906709091

# %% [markdown]
# OK, both methods get the same result (hopefully! if not, something is wrong with your code!). Which one do you think is better? One criterion for "better" is how long it takes for computer to run your code. Let's measure it for both cases!
#
# Python has multiple modules to help you to measure the amount of time it takes to execute a piece of code. Create two new CODE boxes below (There is a ""+ CODE" on top right-hand side. By clicking it a new code boxes pops up. You can also create a new TEXT box wherever you like to comment your code). Copy and paste your looping implementation and vector implementation, and execute them, but this time measure the execution time.

# %%
import time 
st = time.time()

product = 0
for i in range (array_size):
  product += my_array1[i] * my_array2[i]
ed = time.time()

print(ed - st)
# Out:
# 4.339474678039551

# %%
import time
import numpy as np
st = time.time()

np.dot(my_array1, my_array2)

ed = time.time()
print (ed - st)
# Out:
# 0.022381067276000977
